# %% [markdown]
# ## Top block
# * инициализировать все параметры внутри класса
# * взять контекст
#     * взять разделение дат по интервалу
#     * Для каждого предмета из списка:
#         * сделать словарь фильтрации исходя из get_by
#         * отфильтровать выбранные данные
#         * для каждого диапазона дат провести агрегацию данных
#         * вернуть список агрегированных данных и список разделенных дат(не обязательно)
# * Создать контекст, куда включить отформатированный список диапазона дат и датасет
# * если необходимо, взять дополнительный контекст(здесь наследники будут решать самостоятельно
#  что им надо).

# %% [markdown]
# ## Middle-down block
# * инициализировать все параметры внутри класса
# * взять контекст
#     * взять разделение дат по интервалу
#     * Для каждого предмета из списка:
#         * сделать словарь фильтрации исходя из get_by(с объединением в цепочку фильтрации)
#         * отфильтровать выбранные данные
#         * сделать список значений исходя из get_by
#         * для каждого значения:
#             * сделать словарь фильтации исходя из get_by
#             * выполнить агрегацию согласно словарю фильтрации
#             * добавить в контекст агрегированные данные
#         * вернуть список агрегированных данных
# * выполнить предыдущие шаги для первого предмета из списка
# * Создать контекст, куда включить отформатированный список диапазона дат и датасет
# * если необходимо, взять дополнительный контекст(здесь наследники будут решать самостоятельно
#  что им надо).
